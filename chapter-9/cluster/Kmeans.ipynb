# %% [markdown]
# # 9.6 文本聚类实战

# %%
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer

# %%
book_data = pd.read_csv('data/data.csv') #读取文件
print(book_data.head())
book_titles = book_data['title'].tolist()
book_content = book_data['content'].tolist()
print('书名:', book_titles[0])
print('内容:', book_content[0][:10])
from normalization import normalize_corpus
# normalize corpus
norm_book_content = normalize_corpus(book_content)
# Out:
#     title         tag                                              info  \
# 0  ﻿解忧杂货店  豆瓣图书标签: 小说         [日] 东野圭吾 / 李盈春 / 南海出版公司 / 2014-5 / 39.50元
# 1   巨人的陨落  豆瓣图书标签: 小说  [英] 肯·福莱特 / 于大卫 / 江苏凤凰文艺出版社 / 2016-5-1 / 129.80元
# 2   我的前半生  豆瓣图书标签: 小说                     亦舒 / 新世界出版社 / 2007-8 / 22.00元
# 3    百年孤独  豆瓣图书标签: 小说   [哥伦比亚] 加西亚·马尔克斯 / 范晔 / 南海出版公司 / 2011-6 / 39.50元
# 4   追风筝的人  豆瓣图书标签: 小说     [美] 卡勒德·胡赛尼 / 李继宏 / 上海人民出版社 / 2006-5 / 29.00元
#
#       comments                                            content
# 0  (225675人评价)  现代人内心流失的东西，这家杂货店能帮你找回——\r\n僻静的街道旁有一家杂货店，只要写下烦恼...
# 1   (22536人评价)  在第一次世界大战的硝烟中，每一个迈向死亡的生命都在热烈地生长——威尔士的矿工少年、刚失恋的美...
# 2   (20641人评价)  一个三十几岁的美丽女人子君，在家做全职家庭主妇。却被一个平凡女人夺走丈夫，一段婚姻的失败，让...
# 3  (111883人评价)  《百年孤独》是魔幻现实主义文学的代表作，描写了布恩迪亚家族七代人的传奇故事，以及加勒比海沿岸...
# 4  (278905人评价)  12岁的阿富汗富家少爷阿米尔与仆人哈桑情同手足。然而，在一场风筝比赛后，发生了一件悲惨不堪的...
# 书名: ﻿解忧杂货店
# 内容: 现代人内心流失的东西
# Building prefix dict from the default dictionary ...
# Loading model from cache C:\Users\ADMINI~1\AppData\Local\Temp\jieba.cache
# Loading model cost 1.521 seconds.
# Prefix dict has been built succesfully.

# %% [markdown]
# #### 特征提取（TFIDF）

# %%
def build_feature_matrix(documents, feature_type='frequency',
                         ngram_range=(1, 1), min_df=0.0, max_df=1.0):
    feature_type = feature_type.lower().strip()

    if feature_type == 'binary':
        vectorizer = CountVectorizer(binary=True,
                                     max_df=max_df, ngram_range=ngram_range)
    elif feature_type == 'frequency':
        vectorizer = CountVectorizer(binary=False, min_df=min_df,
                                     max_df=max_df, ngram_range=ngram_range)
    elif feature_type == 'tfidf':
        vectorizer = TfidfVectorizer()
    else:
        raise Exception("Wrong feature type entered. Possible values: 'binary', 'frequency', 'tfidf'")

    feature_matrix = vectorizer.fit_transform(documents).astype(float)

    return vectorizer, feature_matrix

# %%
vectorizer, feature_matrix = build_feature_matrix(norm_book_content,
                                                  feature_type='tfidf',
                                                  min_df=0.2, max_df=0.90,
                                                  ngram_range=(1, 2))

# %%
# 查看特征数量
print(feature_matrix.shape)
# Out:
# (5645, 21038)

# %%
# 获取特征名字
feature_names = vectorizer.get_feature_names()
# 打印某些特征
print(feature_names[:10])
# Out:
# ['000', '001', '002', '004', '01', '025', '027', '037', '07', '08']

# %% [markdown]
# ## K means  聚类

# %% [markdown]
# - 此处设置 k = 10

# %%
from sklearn.cluster import KMeans
def k_means(feature_matrix, num_clusters=10):
    km = KMeans(n_clusters=num_clusters,
                max_iter=10000)
    km.fit(feature_matrix)
    clusters = km.labels_
    return km, clusters


num_clusters = 10
km_obj, clusters = k_means(feature_matrix=feature_matrix,
                           num_clusters=num_clusters)
book_data['Cluster'] = clusters

# %% [markdown]
# #### 打印每个cluster的书籍

# %%
from collections import Counter
c = Counter(clusters)
print(c.items())
# Out:
# dict_items([(6, 347), (1, 865), (0, 486), (5, 177), (4, 2715), (3, 229), (2, 480), (9, 115), (7, 51), (8, 180)])

# %%
def get_cluster_data(clustering_obj, book_data,
                     feature_names, num_clusters,
                     topn_features=10):
    cluster_details = {}
    # 获取cluster的center
    ordered_centroids = clustering_obj.cluster_centers_.argsort()[:, ::-1]
    # 获取每个cluster的关键特征
    # 获取每个cluster的书
    for cluster_num in range(num_clusters):
        cluster_details[cluster_num] = {}
        cluster_details[cluster_num]['cluster_num'] = cluster_num
        key_features = [feature_names[index]
                        for index
                        in ordered_centroids[cluster_num, :topn_features]]
        cluster_details[cluster_num]['key_features'] = key_features

        books = book_data[book_data['Cluster'] == cluster_num]['title'].values.tolist()
        cluster_details[cluster_num]['books'] = books

    return cluster_details


def print_cluster_data(cluster_data):
    # print cluster details
    for cluster_num, cluster_details in cluster_data.items():
        print('Cluster {} details:'.format(cluster_num))
        print('-' * 20)
        print('Key features:', cluster_details['key_features'])
        print('book in this cluster:')
        print(', '.join(cluster_details['books']))
        print('=' * 40)

## 绘图
def plot_clusters(num_clusters, feature_matrix,
                  cluster_data, book_data,
                  plot_size=(16, 8)):
    # generate random color for clusters
    def generate_random_color():
        color = '#%06x' % random.randint(0, 0xFFFFFF)
        return color

    # define markers for clusters
    markers = ['o', 'v', '^', '<', '>', '8', 's', 'p', '*', 'h', 'H', 'D', 'd']
    # build cosine distance matrix
    cosine_distance = 1 - cosine_similarity(feature_matrix)
    # dimensionality reduction using MDS
    mds = MDS(n_components=2, dissimilarity="precomputed",
              random_state=1)
    # get coordinates of clusters in new low-dimensional space
    plot_positions = mds.fit_transform(cosine_distance)
    x_pos, y_pos = plot_positions[:, 0], plot_positions[:, 1]
    # build cluster plotting data
    cluster_color_map = {}
    cluster_name_map = {}
    for cluster_num, cluster_details in cluster_data[0:500].items():
        # assign cluster features to unique label
        cluster_color_map[cluster_num] = generate_random_color()
        cluster_name_map[cluster_num] = ', '.join(cluster_details['key_features'][:5]).strip()
    # map each unique cluster label with its coordinates and books
    cluster_plot_frame = pd.DataFrame({'x': x_pos,
                                       'y': y_pos,
                                       'label': book_data['Cluster'].values.tolist(),
                                       'title': book_data['title'].values.tolist()
                                       })
    grouped_plot_frame = cluster_plot_frame.groupby('label')
    # set plot figure size and axes
    fig, ax = plt.subplots(figsize=plot_size)
    ax.margins(0.05)
    # plot each cluster using co-ordinates and book titles
    for cluster_num, cluster_frame in grouped_plot_frame:
        marker = markers[cluster_num] if cluster_num < len(markers) \
            else np.random.choice(markers, size=1)[0]
        ax.plot(cluster_frame['x'], cluster_frame['y'],
                marker=marker, linestyle='', ms=12,
                label=cluster_name_map[cluster_num],
                color=cluster_color_map[cluster_num], mec='none')
        ax.set_aspect('auto')
        ax.tick_params(axis='x', which='both', bottom='off', top='off',
                       labelbottom='off')
        ax.tick_params(axis='y', which='both', left='off', top='off',
                       labelleft='off')
    fontP = FontProperties()
    fontP.set_size('small')
    ax.legend(loc='upper center', bbox_to_anchor=(0.5, -0.01), fancybox=True,
              shadow=True, ncol=5, numpoints=1, prop=fontP)
    # add labels as the film titles
    for index in range(len(cluster_plot_frame)):
        ax.text(cluster_plot_frame.ix[index]['x'],
                cluster_plot_frame.ix[index]['y'],
                cluster_plot_frame.ix[index]['title'], size=8)
        # show the plot
    plt.show()

# %%
cluster_data = get_cluster_data(clustering_obj=km_obj,
                                book_data=book_data,
                                feature_names=feature_names,
                                num_clusters=num_clusters,
                                topn_features=5)

print_cluster_data(cluster_data)
# Out:
# Cluster 0 details:
# --------------------
# Key features: ['没有', '女人', '一个', '为什么', '开始']
# book in this cluster:
# 我的前半生, 新名字的故事, 月亮和六便士, 杀死一只知更鸟, 斯通纳, 新名字的故事, 月亮和六便士, 杀死一只知更鸟, 斯通纳, 我的天才女友, 月亮和六便士, 杀死一只知更鸟, 江城, 爱你就像爱生命, 杀死一只知更鸟, 白夜行, 强风吹拂, 咖啡未冷前, 国境以南 太阳以西, 二十首情诗与绝望的歌, 爱德华的奇妙之旅, 爱你就像爱生命, 我的精神家园, 似水流年, 我的精神家园, 爱德华的奇妙之旅, 《噼里啪啦系列》, 月亮和六便士, 没有一条道路是重复的, 我没有自己的名字, 红玫瑰与白玫瑰, 一个陌生女人的来信, 鲁迅杂文全集, 一个陌生女人的来信, 恐惧, 茨威格小说集, 一个陌生女人的来信, 慢, 庆祝无意义, 身份, ﻿白夜行, 嫌疑人X的献身, 半落, 放学后, 1995-2005夏至未至, 坏一坏, 致我们终将逝去的青春, 微微一笑很倾城, 白夜行, 嫌疑人X的献身, 放学后, 祈祷落幕时, ﻿三体, 银河系漫游指南, 神们自己, 球状闪电, 那个不为人知的故事, 微微一笑很倾城, 他知道风从哪个方向来, 曾有一个人，爱我如生命, 海棠依舊: 知否? 知否? 應是綠肥紅瘦 卷一, ﻿白夜行, 嫌疑人X的献身, ﻿散步去, 他的国, 又一春, 她比烟花寂寞, 开到荼蘼, 人淡如菊, 朝花夕拾, 乐未央, 不羁的风, 阿修罗, ﻿白夜行, 嫌疑人X的献身, 半落, 放学后, 一朵桔梗花, 我的宝贝, 倾城, 明朝那些事儿（壹）, 那个不为人知的故事, 致我们终将逝去的青春, 海棠依舊: 知否? 知否? 應是綠肥紅瘦 卷一, ﻿1995-2005夏至未至, 夏至未至, 海棠依舊: 知否? 知否? 應是綠肥紅瘦 卷一, 步步惊心, 凤囚凰（上中）, 绾青丝Ⅰ, 渴望死亡的小丑, 尼罗河上的惨案, 罗杰疑案, 阿加莎·克里斯蒂侦探推理“波洛”系列（全32册）, 阳光下的罪恶, 无尽长夜, 我的心中每天开出一朵花, 微笑的鱼, ﻿三体, 银河系漫游指南, 神们自己, 球状闪电, 仿生人会梦见电子羊吗？, 我偏爱那些不切实际的浪漫, 愿你迷路到我身旁, 那个不为人知的故事, 1995-2005夏至未至, 神奇动物在哪里, 我的前半生, 任你行, 我的心中每天开出一朵花, 微笑的鱼, 神奇动物在哪里, 罪恶生涯, 神奇的魁地奇球, 一个人去跑步, 忘川 上, 大漠荒颜, 忘川 下, 剩者为王Ⅱ, 文艺风象·闪开！让专业不对口的来, 17, 微微一笑很倾城, ﻿人类简史, 枪炮、病菌与钢铁, 明朝那些事儿（壹）, 人类简史, 失控, 苏菲的世界, ﻿人类简史, 失控, 枪炮、病菌与钢铁, 枪炮、病菌与钢铁, 人类简史, 做衣服, ﻿人类简史, 枪炮、病菌与钢铁, 江城, 杀死一只知更鸟, 独裁者手册, 毛泽东选集 第一卷, ﻿悉达多, 西藏生死书, 独裁者手册, 明朝那些事儿（壹）, 失控, 我的精神家园, 毛泽东选集 第一卷, 乐之本事, ﻿人类简史, 佛祖都说了些什么?, 悉达多, 致命的自负, 常识, 透视的艺术, ﻿我的前半生, 爱你就像爱生命, 一个陌生女人的来信, 江城, 岛上书店, 遇见未知的自己, 把小日子收进手帐里, 杀死一只知更鸟, 我的前半生, 被讨厌的勇气, 偷影子的人, 强风吹拂, 拆掉思维里的墙, 别让将来的你，讨厌现在不理智的自己, 活法, 你不用假装过得很好, ﻿我的前半生, 新名字的故事, 长恨歌, 如何让女人免于心碎, 学会提问, 鸭川食堂, 杀死一只知更鸟, 孩子的宇宙, 江城, ﻿遇见未知的自己, 当下的力量, 观呼吸, 乳房, 消失的微生物, 我偏爱那些不切实际的浪漫, 萤火虫小巷, 爱得太多的女人, 我有个恋爱想和你谈下, 男人来自火星 女人来自金星, 原谅石, 世上另一个我(修订版), 男人来自火星 女人来自金星, 極致挑逗：雙人共撫全圖解120招, 搞定男人, 男人不屌女人不High, 吸引力是这样炼成的, 激荡三十年（上）, 大国大城, 致命的自负, 激荡三十年（上）, 大国大城, 致命的自负, 激荡三十年（上）, 货币战争, 无价, 创意, ﻿激荡三十年（上）, ﻿创意, 疯传, 时尚：幕后的策动, 人类简史, ﻿失控, 启示录, C程序设计语言, ﻿启示录, ﻿启示录, C程序设计语言, 迷人的材料, 星际唱片, C程序设计语言, 三体, 白夜行, 嫌疑人X的献身, 我的天才女友, 我的天才女友, 三体, 白夜行, 回答不了, 三体, 三体, 白夜行, 嫌疑人X的献身, 白夜行, 爱你就像爱生命, 假如真有时光机, 国境以南 太阳以西, 二十首情诗与绝望的歌, 父与子全集, 爱你就像爱生命, 我的精神家园, 我的精神家园, 爱你就像爱生命, 红玫瑰与白玫瑰, 红玫瑰与白玫瑰, 一个陌生女人的来信, ﻿一个陌生女人的来信, 一个陌生女人的来信, 一个陌生女人的来信, 一个女人一生中的二十四小时, 庆祝无意义, 慢, 烈女圖, 回答不了, 父与子全集, ﻿白夜行, 嫌疑人X的献身, 白夜行, 放学后, 嫌疑人X的献身, 无人生还, 回答不了, 父与子全集, 白夜行, 嫌疑人X的献身, 白夜行, 放学后, 嫌疑人X的献身, 危险的维纳斯, ﻿三体, 球状闪电, 流浪地球, 神们自己, ﻿白夜行, 嫌疑人X的献身, 白夜行, 放学后, 嫌疑人X的献身, 无人生还, 步步惊心, 微微一笑很倾城, 楚楚很动人, 散步去, 漩涡, ﻿白夜行, 嫌疑人X的献身, 放学后, 白夜行, 无人生还, 无人生还, 尼罗河上的惨案, 他的国, 我的前半生, 她比烟花寂寞, 开到荼蘼, 朝花夕拾, 人淡如菊, 喜宝, 阿修罗, 不羁的风, 明朝那些事儿（壹）, 步步惊心, 我的宝贝, ﻿三体, 球状闪电, 流浪地球, 神们自己, 无人生还, 无人生还, 尼罗河上的惨案, 尼罗河上的惨案, 罗杰疑案, 阳光下的罪恶, 步步惊心, 海棠依舊: 知否? 知否? 應是綠肥紅瘦 卷一, 绾青丝Ⅰ, 蔓蔓青萝（全2册）, 楚楚很动人, 凤囚凰（上中）, 凤囚凰, 夏至未至, 1995-2005夏至未至, 1995-2005夏至未至, 我的青春恋爱喜剧果然有问题 01, 渴望死亡的小丑, 东霓, 1995-2005夏至未至, 夏至未至, 微微一笑很倾城, 我的心中每天开出一朵花, 月亮忘记了, 微笑的鱼, 不爱读书不是你的错, 故事团团转, 月亮忘记了, 我的心中每天开出一朵花, 故事的开始, 不爱读书不是你的错, 微笑的鱼, 拥抱, ﻿面包树上的女人, 谢谢你离开我, 后来我学会了爱自己, 面包树上的女人, 三个A Cup的女人, 我这辈子有过你, 谢谢你离开我（精装版）, 面包树出走了, 神奇动物在哪里, 一个人的小繁华①, 忘川 上, 大漠荒颜, 忘川 下, 镜·龙战（下）, 微微一笑很倾城, 夏至未至, 橘生淮南·暗恋, 致我们单纯的小美好, 我的天, 全宇宙至此剧终1, 全宇宙至此剧终2, 剩者为王Ⅱ, 剩者为王Ⅰ, 17, 鲤·猫知道一切, 鲤·一间不属于自己的房间, 人类简史, 明朝那些事儿（壹）, 枪炮、病菌与钢铁, 被讨厌的勇气, 遇见未知的自己, 人类简史, 三体, 苏菲的世界, 被讨厌的勇气, 人类简史, 枪炮、病菌与钢铁, 回答不了, 大国大城, ﻿人类简史, 明朝那些事儿（壹）, 月亮和六便士, 雕刻时光, 人类简史, 杀死一只知更鸟, 人类简史, 毛泽东选集 第一卷, 独裁者手册, 悉达多, 西藏生死书, 佛祖都说了些什么?, 雕刻时光, 希望为电影, 独裁者手册, ﻿明朝那些事儿（壹）, 苏菲的世界, 我的精神家园, 毛泽东选集 第一卷, 失控, ﻿人类简史, 枪炮、病菌与钢铁, 乐之本事, 我的手绘不可能这么萌：萌系手帐插画教程, ﻿苏菲的世界, 激荡三十年, ﻿悉达多, 西藏生死书, 佛祖都说了些什么?, 悉达多, 致命的自负, 常识, 白夜行, 嫌疑人X的献身, 一个陌生女人的来信, 爱你就像爱生命, 杀死一只知更鸟, 偷影子的人, 假如真有时光机, 江城, 回答不了, 云边有个小卖部, 岛上书店, 被讨厌的勇气, 遇见未知的自己, 遇见未知的自己, 我的天才女友, 新名字的故事, 离开的，留下的, 一个陌生女人的来信, 红玫瑰与白玫瑰, 成为母亲, 长恨歌, 手机摄影从小白到大师, 杀死一只知更鸟, 鸭川食堂, 假如真有时光机, ﻿遇见未知的自己, 当下的力量, 悉达多, 西藏生死书, 当下的力量, 病者生存, ﻿云边有个小卖部, 亲密关系（第6版）, 萤火虫小巷, 男人来自火星 女人来自金星, 假性亲密关系, 亲密关系（第6版）, 男人来自火星 女人来自金星, 亲密关系（第6版）, 男人来自火星，女人来自金星, 女人这东西, 男人来自火星，女人来自金星2, 脾虚的女人老得快, 大国大城, 激荡三十年（上）, 激荡三十年（上）, 大国大城, 激荡三十年, 货币战争, 激荡三十年（上）, 激荡三十年, 货币战争, 周期, 周期, 创意, 一个广告人的自白, 给新手的极简股票课, 激荡三十年（上）, 激荡三十年, 激荡三十年, 创意, 疯传, ﻿人类简史, 三体, 失控, 启示录, C程序设计语言, 人类简史, 流浪地球, 启示录, 启示录, 算法笔记, 迷人的材料, 启示录, 启示录
# ========================================
# Cluster 1 details:
# --------------------
# Key features: ['小说', '一个', '作品', '故事', '一部']
# book in this cluster:
# 巨人的陨落, 世界的凛冬, 霍乱时期的爱情, 巨人的陨落, 霍乱时期的爱情, 世界的凛冬, 巨人的陨落, 世界的凛冬, 霍乱时期的爱情, 步履不停, 看见, 目送, 浮生六记, 亲爱的安德烈, 皮囊, 平凡的世界（全三部）, 白鹿原, 繁花, 明朝那些事儿（1-9）, 黄金时代, 台北人, 一句顶一万句, 巨人的陨落, 艺术的故事, 世界的凛冬, 平凡的世界（全三部）, 小王子, 刀锋, 永恒的边缘, 我的职业是小说家, 挪威的森林, 不可思议的朋友, 怒, 火花, 海边的卡夫卡, 世界尽头与冷酷仙境, 目送, 浮生六记, 皮囊, ﻿我的职业是小说家, 海边的卡夫卡, 世界尽头与冷酷仙境, 挪威的森林, 没有色彩的多崎作和他的巡礼之年, 且听风吟, 奇鸟行状录, 我的孤独是一座花园, ﻿最后的精灵, 小王子, 王尔德童话, 当世界年纪还小的时候, 天蓝色的彼岸, 彼得·潘, 安吉拉·卡特的精怪故事集, 黄金时代, 思维的乐趣, 青铜时代, 绿毛水怪, 白银时代, 黑铁时代, 黑铁时代, 呐喊, 思维的乐趣, ﻿不可思议的朋友, 窗边的小豆豆, 我亲爱的甜橙树, 绿山墙的安妮, 草房子, 当世界年纪还小的时候, 天蓝色的彼岸, 彼得·潘, 浮生六记, 基督山伯爵, 傲慢与偏见, 荆棘鸟, 查特莱夫人的情人, 了不起的盖茨比, 罪与罚, 红与黑, 约翰·克利斯朵夫, 麦琪的礼物, 许三观卖血记, 兄弟（上）, 在细雨中呼喊, 兄弟, 余华作品系列（共12册）, 我胆小如鼠, 金锁记, 小团圆, 张爱玲作品集, 一句顶一万句, 繁花, 小说课, 阿城精选集, 平原上的摩西, 尘埃落定, 蒙着眼睛的旅行者, 丙申故事集, 基督山伯爵, 傲慢与偏见, 红与黑, 麦琪的礼物, 双城记, 巴黎圣母院, 羊脂球, 包法利夫人, 等待戈多, ﻿呐喊, 彷徨, 故事新编, 故事新编, 鲁迅小说全集, 浮生六记, 昨日的世界, 象棋的故事, 一个陌生女子的来信, 昨日之旅, 茨威格文集, 一个陌生女人的来信, 情感的迷惘, 蒙田, ﻿不能承受的生命之轻, 生活在别处, 小说的艺术, 笑忘录, 玩笑, 无知, 告别圆舞曲, 帷幕, 阿涅丝的最后一个下午, 欲望玫瑰, 中国北方的情人, 物质生活, 平静的生活, 劳儿之劫, 毁灭，她说, 直布罗陀水手, 爱, 无耻之徒, 夏夜十点半钟, 小说稗类, 鳄鱼手记, 纽约客, 寂寞的十七岁, 阿兰的战争, 一日谈, 东方快车谋杀案, 幽灵, 猎豹, 向左走·向右走, 这些都是你给我的爱, 不可思议的朋友, 我怎样毁了我的一生, 松风, ﻿挪威的森林, 一个人的好天气, 此间的少年, 从你的全世界路过, 陪安东尼度过漫长岁月, 何以笙箫默, 浪花少年侦探团, 永恒的终结, 献给阿尔吉侬的花束, 沙丘, 海伯利安, 神经漫游者, ﻿有匪1, 三生三世 十里桃花, 何以笙箫默, 完美爱情标本店, 浮生若梦1, 幽灵, 猎豹, 螺旋之谜, 怒, 香水, 达·芬奇密码, 夜色人生, ﻿有匪1, 笑傲江湖（全四册）, 鹿鼎记（全五册）, 剑桥简明金庸武侠史, 有匪3, 英雄志（全三册）, 金庸师承考, 陆小凤传奇, 欢乐英雄, 多情剑客无情剑(上、中、下), 冰与火之歌（卷一）, 克苏鲁神话, 魔戒, 魔法坏女巫, 铳梦, 異變者1, ﻿1988：我想和这个世界谈谈, 我所理解的生活, 一座城池, 很高兴见到你, 像少年啦飞驰, 三重门, 告白与告别, 零下一度, 通稿2003, 如果墙会说话, 吃南瓜的人, 东方快车谋杀案, 怒, 夜色人生, 万水千山走遍, ﻿悟空传, 有匪1, 三生三世 十里桃花, 明朝那些事儿（1-9）, 何以笙箫默, 此间的少年, 天行健（全4册）, 彼岸花, 八月未央, 春宴, 二三事, 告别薇安, 瞬间空白, 素年锦时之月棠记, 深白, 梦里花落知多少, 幻城, 小时代1.0折纸时代, 临界·爵迹 I, 临界·爵迹 Ⅱ, 小时代2.0虚铜时代, 爱与痛的边缘, 小时代3.0：刺金时代, 天亮说晚安, 愿风裁尘, 小时代1.5·青木时代VOL.1, 爵迹：雾雪零尘, 庆余年·壹, 新宋, 窃明, 笑傲江湖（全四册）, 鹿鼎记（全五册）, 侠客行, 金庸十二钗, 金庸师承考, 雪山飞狐, 书剑恩仇录(上下), 飞狐外传(上下), 剑桥简明金庸武侠史, ﻿东方快车谋杀案, ﻿向左走·向右走, 走向春天的下午, 躲进世界的角落, 听幾米唱歌, 遗失了一只猫, 永恒的终结, 沙丘, 海伯利安, 神经漫游者, 索拉里斯星, 每天早上和你一起醒来, 请你永远记得我, 最初不过你好, ﻿冰与火之歌（卷一）, 魔法坏女巫, 松风, 魔戒, 魔戒（第一部）, 喜宝, 霸王别姬 青蛇, 迷楼, ﻿向左走·向右走, 走向春天的下午, 躲进世界的角落, 听幾米唱歌, 遗失了一只猫, 哈利·波特与被诅咒的孩子, 一个人住的每一天, 一个人旅行2, 人气绘本天后高木直子作品典藏（全6册）, 一个人的第一次 第一次一个人旅行, 一个人的美食之旅2, ﻿欢乐英雄, 陆小凤传奇, 多情剑客无情剑(上、中、下), 楚留香传奇, 笑红尘, 天涯·明月·刀, 边城浪子（上下）, 武林外史（上下）, 楚留香传奇系列, 白玉老虎（上下）, 镜·神寂, 羽·青空之蓝, 镜·龙战, 镜·辟天, 镜·织梦者, ﻿那些生命中温暖而美好的事情, 如果声音不记得, 鲤·嫉妒, 樱桃之远, 誓鸟, 十爱, 葵花走失在1890, 此间的少年, 聋哑时代, 三重门, 我们纯真的青春, 会有天使替我爱你, 草样年华, 那些回不去的年少时光（套装上下册）, 巨人的陨落, 世界的凛冬, 明朝那些事儿（1-9）, 如果没有今天，明天会不会有昨天？, 如果没有今天，明天会不会有昨天？, 禅与摩托车维修艺术, 昨日的世界, 艺术的故事, 娱乐至死, 看见, ﻿艺术的故事, 娱乐至死, 一九八四·动物农场, 我的应许之地, 穆斯林的葬礼, 达·芬奇密码, 我的应许之地, 剧本, 异形全书：经典四部曲终极档案, 昨日的世界, 被淹没和被拯救的, 巨流河, 辛丰年音乐笔记, 曾国藩（上中下）, 褚时健传, 茶馆, 等待戈多, 奥狄浦斯王, 中央公园西路, ﻿艺术的故事, 自制美学, 写给大家的西方美术史, 亮剑, ﻿世界的凛冬, 阿兰的战争, 零年：1945, 五个人的战争, 像自由一样美丽, 如果没有今天，明天会不会有昨天？, 开放社会及其敌人（全二卷）, 霍乱时期的爱情, 挪威的森林, 平如美棠, 傲慢与偏见, 荆棘鸟, 穆斯林的葬礼, 喜宝, 面纱, 爱情和其他魔鬼, 罗摩桥, 如果没有今天，明天会不会有昨天？, 平如美棠, 皮囊, 皮囊, 喜宝, 有匪1, 富爸爸，穷爸爸, 布鲁克林有棵树, 滚蛋吧!肿瘤君, 摄影师, 使女的故事, 面纱, 另一座城, ﻿深度工作, 杜拉拉升职记, 至味在人间, 亲爱的安德烈, 窗边的小豆豆, 罗摩桥, 喜宝, 每天早上和你一起醒来, 请你永远记得我, 我把欧洲塞进背包, 定位, 定位, 富爸爸，穷爸爸, 定位, 世界上最伟大的推销员, 富爸爸，穷爸爸, 小狗钱钱, 定位, 史丹·温斯坦称傲牛熊市的秘密, 光变：一个企业及其工业史, 迪斯尼战争, 绩效致死, 会讲故事，让世界听你的, 万物简史, 上帝的手术刀, 支付战争, 活着, 房思琪的初恋乐园, 小王子, 平凡的世界（全三部）, 霍乱时期的爱情, 许三观卖血记, 挪威的森林, 小王子, 霍乱时期的爱情, 傲慢与偏见, 鲁滨逊漂流记, 不能承受的生命之轻, 达·芬奇密码, 我们一无所有, 了不起的盖茨比, 活着, 小王子, 平凡的世界（全三部）, 霍乱时期的爱情, 房思琪的初恋乐园, 边城, 许三观卖血记, 不能承受的生命之轻, 看见, 目送, 浮生六记, 皮囊, 亲爱的安德烈, 我与地坛, ﻿活着, 平凡的世界（全三部）, 许三观卖血记, 边城, 骆驼祥子, 穆斯林的葬礼, 白鹿原, 房思琪的初恋乐园, 黄金时代, 呐喊, ﻿小王子, 活着, 平凡的世界（全三部）, 傲慢与偏见, 骆驼祥子, 鲁滨逊漂流记, 边城, 霍乱时期的爱情, 许三观卖血记, 挪威的森林, 窗边的小豆豆, 挪威的森林, 海边的卡夫卡, 拍电影时我在想的事, 目送, 皮囊, 浮生六记, 我与地坛, 亲爱的安德烈, ﻿挪威的森林, 挪威的森林, 海边的卡夫卡, 且听风吟, 我的职业是小说家, 世界尽头与冷酷仙境, 海边的卡夫卡, 挪威的森林, 我的孤独是一座花园, ﻿小王子, 窗边的小豆豆, 黑塞童话集, 向左走·向右走, 安吉拉·卡特的精怪故事集, ﻿小王子, 窗边的小豆豆, 草房子, 绿山墙的安妮, 青铜葵花, 浮生六记, 儒林外史, 骆驼祥子, 鲁滨逊漂流记, 傲慢与偏见, 基督山伯爵, 霍乱时期的爱情, 巴黎圣母院, 了不起的盖茨比, 羊脂球, ﻿黄金时代, 白银时代, 黄金时代, 绿毛水怪, 绿毛水怪, 黄金时代, 青铜时代, 爱你就像爱生命, 思维的乐趣, 黄金时代, 呐喊, 无所畏, 我所理解的生活, 1988：我想和这个世界谈谈, ﻿活着, 许三观卖血记, 许三观卖血记, 兄弟, 兄弟（上）, 在细雨中呼喊, 活着, 在细雨中呼喊, 兄弟, 许三观卖血记, 黄昏里的男孩, 金锁记, 小团圆, 小团圆, 少帅, ﻿活着, 平凡的世界（全三部）, 许三观卖血记, 穆斯林的葬礼, 白鹿原, 尘埃落定, 兄弟, 黄金时代, 一句顶一万句, 平凡的世界, 在细雨中呼喊, 活着, 围城, 围城, ﻿傲慢与偏见, 鲁滨逊漂流记 ...
# ========================================
# Cluster 2 details:
# --------------------
# Key features: ['本书', '包括', '介绍', '内容', '理论']
# book in this cluster:
# 鱼王, 鱼王, 鱼王, ﻿沉默的大多数, 沉默的大多数, 认识电影, 经济学原理（上下）, 我口袋里的星辰如沙砾, 格林童话全集, ﻿沉默的大多数, 寻找无双·东宫西宫, ﻿沉默的大多数, 老人与海, 人·兽·鬼, 老人与海, 野草, 魏晋风度及其他, 巴西：未来之国, 相遇, 我口袋里的星辰如沙砾, 伽利略的苦恼, 走进大文豪的家, 滚滚红尘, 蔷薇岛屿, 大方 No.1, 古书之美, 我口袋里的星辰如沙砾, 原来你非不快乐, 亲密关系（第5版）, 进化心理学, 理想国, 大问题, 规训与惩罚, 逻辑学导论, 社会契约论, 作为意志和表象的世界, 忧郁的热带, 忧郁的热带, 认识电影, 认识艺术（全彩插图第8版）, 利维坦, 建筑十书, ﻿认识电影, 石挥谈艺录, 怎样解题, 概率论与数理统计, 线性代数及其应用, 微积分学教程（第一卷）, 离散数学及其应用（原书第5版）, 社会契约论, 利维坦, 国家的常识, 论自由, 中国通史, ﻿沉默的大多数, 进化心理学, 规训与惩罚, 作为意志和表象的世界, 哲学的故事, 论自由, 听音乐（插图第6版）, 怎样欣赏音乐, 西方文明中的音乐, 认识电影, 大问题, 我也有一个梦想, 硅谷钢铁侠, 像艺术家一样思考, 伯里曼人体结构绘画教学, 水彩入门, 石挥谈艺录, 认识艺术（全彩插图第8版）, 佛教常识答问, 竞逐富强, 艾希曼在耶路撒冷, 理想国, 大问题, 作为意志和表象的世界, 纯粹理性批判, 规训与惩罚, 哲学的故事, 逻辑哲学论, 叔本华思想随笔, 查拉图斯特拉如是说, 谈谈方法, 宗子维城, 汉代物质文化资料图说, 论自由, 自由秩序原理, 一课经济学, 无政府、国家和乌托邦, 法律、立法与自由(第一卷), 自由的伦理, 扭曲的人性之材, 伯里曼人体结构绘画教学, 像艺术家一样思考, 亲密关系（第5版）, 我口袋里的星辰如沙砾, 亲密关系（第5版）, 我口袋里的星辰如沙砾, 把时间当作朋友, 把时间当作朋友, 人性的弱点全集, 亲密关系（第5版）, 进化心理学, 摄影构图学, 论摄影, Excel图表之道, 小强升职记, 食帖·真的，烤箱什么都能做, 四季便当, 生命之书, 生命的轨迹, 手作族一定要会的缝纫基本功, 爱上有缝纫机的日子, 从零开始学缝纫, 皮革工藝. vol.9 基礎技法篇, 亲密关系（第5版）, 完美关系的秘密, 人体使用手册, 范志红：不懂健康，难做美丽女人, 养生书, 亲密关系（第5版）, 人情与面子, 收纳全书, 明天就去尼泊尔, ﻿经济学原理（上下）, 国富论, 管理的实践, 金字塔原理, ﻿经济学原理（上下）, 国富论, 硅谷钢铁侠, ﻿聪明的投资者, 投资中最简单的事, 金融炼金术, 货币金融学, 期货市场技术分析, 漫步华尔街, 聪明的投资者, 投资中最简单的事, 期货市场技术分析, 金融炼金术, 漫步华尔街, 一个广告人的自白, 消费者行为学 （第8版·中国版）, 市场营销原理, 不做无效的营销, 超级符号就是超级创意, 硅谷钢铁侠, ﻿聪明的投资者, 投资中最简单的事, 工作前5年，决定你一生的财富, 财务自由之路, 通向财务自由之路, 股市进阶之道, 个人理财, ﻿一个广告人的自白, 计算广告, 超级符号就是超级创意, 投资中最简单的事, 股市进阶之道, 公司价值分析, 专业投机原理, 股票大作手操盘术, 联想风云, 展览实践手册, 活动策划全攻略, 时间简史, 上帝掷骰子吗, 编码, 代码大全（第2版）, 深入理解计算机系统, 算法导论（原书第2版）, 算法（第4版）, 编程珠玑, 集体智慧编程, 编码的奥秘, Python编程：从入门到实践, 程序员的自我修养, 程序员修炼之道, 时间简史, 上帝掷骰子吗, 控制论与科学方法论, 七堂极简物理课, 用户体验的要素, 瞬间之美, Web信息架构(第3版), 用户体验的要素, 瞬间之美, Web信息架构(第3版), 深入理解计算机系统, 机器学习, 编码, 算法导论（原书第2版）, 集体智慧编程, 算法（第4版）, 编程珠玑, 编码的奥秘, 程序员的自我修养, 编译原理, 网络是怎样连接的, 图解HTTP, JAVASCRIPT权威指南(第四版), Flask Web开发：基于Python的Web应用开发实战, 构建高性能Web站点, PHP和MySQL Web开发(原书第4版), Web前端黑客技术揭秘, 硅谷钢铁侠, 什么是科学, 用户体验的要素, 移动应用UI设计模式, ﻿通信之道——从微积分到5G, 大话无线通信, 大话通信, 信号与系统, 无线通信, 大话移动通信, 通信原理, 数据通信与网络, 通信原理, 通信行业求职宝典, 射频和无线技术入门, 通信新读, 信息论基础, 数字通信, 数字通信, 通信之美, 数字通信, 交互式培训, ﻿用户体验的要素, UCD火花集2, 神经网络与机器学习（原书第3版）, 意识的宇宙, 模式识别与神经网络, 神经网络在应用科学和工程中的应用, 神经网络与深度学习, 神经计算原理, 神经网络模型及其MATLAB仿真程序设计, 深度学习, 神经网络, 脑的高级功能与神经网络, MATLAB神经网络原理与实例精解, ﻿"""笨办法""学Python", 计算机程序设计艺术（第1卷）, Head First Python（中文版）, C专家编程, 程序员的自我修养, 机器学习系统设计, Effective java 中文版（第2版）, 高性能网站建设指南, CSS禅意花园, 代码大全（第2版）, Programming Ruby中文版, JAVASCRIPT语言精髓与编程实践, 老人与海, 沉默的大多数, 老人与海, 沉默的大多数, 文化苦旅, 格林童话全集, 格林童话全集, 小狗钱钱, 鬼谷子, 老人与海, 沉默的大多数, ﻿沉默的大多数, 沉默的大多数, 人·兽·鬼, 老人与海, 野草, 十九年间谋杀小叙, 观山海, 十九年间谋杀小叙, 十九年间谋杀小叙, 毒, 蔷薇岛屿, 古书之美, 亲密关系（第5版）, 人性的弱点全集, 态度改变与社会影响, 理想国, 沉默的大多数, 亲密关系（第5版）, 态度改变与社会影响, 沉默的大多数, 文化苦旅, 认识电影, 观看之道, 沉默的大多数, 认识电影, 社会契约论, 政治学通识, 理想国, 国家的常识, 怎样解题, 什么是数学, 线性代数及其应用, 数学家讲解小学数学, 概率论与数理统计, 普林斯顿微积分读本（修订版）, 天才引导的历程, 统计学习方法, 中国通史, ﻿沉默的大多数, 规训与惩罚, 理想国, 鬼谷子, 硅谷钢铁侠, 认识电影, 听音乐（插图第6版）, 小夜曲, 伯里曼人体结构绘画教学, 美国绘画透视完全教程, 理想国, 规训与惩罚, 作为意志和表象的世界, 哲学的故事, 纯粹理性批判, 谈谈方法, 查拉图斯特拉如是说, 艾希曼在耶路撒冷, 孙子兵法, 论自由, 论自由, 无政府、国家和乌托邦, 货币的非国家化, 伯里曼人体结构绘画教学, 隐秘的知识, 小顾聊绘画·贰, 素描的诀窍（15周年畅销版）, 怦然心动的人生整理魔法, 人性的弱点全集, 亲密关系（第5版）, 态度改变与社会影响, 老人与海, 人性的弱点全集, 把时间当作朋友, 论摄影, 摄影构图学, 观看之道, 小狗钱钱, 掌控关系, 忧郁的热带, 蔷薇岛屿, 生命之书, 太傻天书, 饮食的迷思, 你的身体，是一切美好的开始, 亲密关系（第5版）, 掌控关系, 态度改变与社会影响, 掌控关系, 沟通的艺术, ﻿亲密关系（第5版）, 青年恋爱心理学, 木工全书, 手作族一定要会的缝纫基本功, 饮食的迷思, 收纳全书, 经济学原理（上下）, 国富论, 涛动周期论, 奈飞文化手册, 这就是OKR, 人性的弱点全集, 怦然心动的人生整理魔法, 金字塔原理, 小狗钱钱, 经济学原理（上下）, 国富论, 涛动周期论, 奈飞文化手册, 涛动周期论, 公司理财, 小狗钱钱, 涛动周期论, 投资中最简单的事, 财务自由之路, 超级符号就是超级创意, 一个广告人的自白, 引爆点, 小狗钱钱, 财务自由之路, 工作前5年，决定你一生的财富, 财务自由之路, 投资中最简单的事, 邻家的百万富翁, 钱：7步创造终身收入, 硅谷钢铁侠, ﻿一个广告人的自白, 计算广告, 超级符号就是超级创意, 投资中最简单的事, 股市进阶之道, 金融市场技术分析, 冲突, 我知道他想看什么, 展览实践手册, 时间简史, 上帝掷骰子吗, ﻿Python编程, 代码大全（第2版）, 流畅的Python, 编码, 码农翻身, 程序员的自我修养, 编程珠玑, Python深度学习, 从Python开始学编程, Head First 设计模式（中文版）, C Primer Plus（第6版）中文版, ﻿时间简史, 上帝掷骰子吗, 七堂极简物理课, 科学革命的结构, 用户体验的要素, 用户体验的要素, 算法（第4版）, 算法, 算法导论（原书第3版）, 我的第一本算法书, 算法导论（原书第2版）, 编程珠玑, 程序员代码面试指南：IT名企算法与数据结构题目最优解, 算法新解, 机器学习, 剑指Offer：名企面试官精讲典型编程题（第2版）, 计算机程序设计艺术（第1卷）, 剑指Offer, 硅谷钢铁侠, 未来世界的幸存者, 技术的本质, ﻿图解HTTP, Flask Web开发实战, 深入分析Java Web技术内幕（修订版）, Web信息架构(第3版), 大型网站技术架构, 深入浅出Node.js,  ...
# ========================================
# Cluster 3 details:
# --------------------
# Key features: ['生活', '三毛', '文字', '沙漠', '散文']
# book in this cluster:
# 雪落香杉树, 雪落香杉树, 二手时间, 雪落香杉树, 二手时间, 我们仨, 我们仨, 人间草木, 撒哈拉的故事, 当我谈跑步时我谈些什么, 文学回忆录（全2册）, 人间草木, 智惠子抄, ﻿我们仨, 撒哈拉的故事, 人间草木, 孩子你慢慢来, 生活，是很好玩的, 当我谈跑步时我谈些什么, 智惠子抄, 夏洛的网, 牧羊少年奇幻之旅, 常识, 夏洛的网, 柑橘与柠檬啊, 陶庵梦忆 西湖梦寻, 古文观止, 异乡记, 人情之美, 钱钟书散文, 陶庵梦忆 西湖梦寻, 古文观止, 异端的权利, 一個人住第5年, 秘密, 你一生的故事, 雪落香杉树, ﻿撒哈拉的故事, 梦里花落知多少, 哭泣的骆驼, 荷西 我爱你, 温柔的夜, 雨季不再来, 三毛典藏全集, 稻草人手记, 亲爱的三毛, 送你一匹马, 你是我不及的梦, 闹学记, 我的灵魂骑在纸背上, 流星雨, 盗墓笔记, 鬼吹灯之精绝古城, 素年锦时, 且以永日, 雪落香杉树, 我不是完美小孩, 又寂寞又美好, 你一生的故事, 常识, 我不是完美小孩, 又寂寞又美好, ﻿一個人住第5年, 二手时间, 爱的艺术, 爱的艺术, 文学回忆录（全2册）, 智惠子抄, 二手时间, 孤独之间, 二手时间, 正见, ﻿我们仨, 人情之美, 正见, 古文观止, 如果这可以是首歌, 文学回忆录（全2册）, 人间草木, 孤独之间, 孤独之间, 正见, 所有我们看不见的光, 第三帝国的兴亡（上中下）, 爱的艺术, 智惠子抄, 夜航西飞, 撒哈拉的故事, 乖，摸摸头, 最好金龟换酒, 当我谈跑步时我谈些什么, 把力气花在你想要的生活上, 爱的艺术, 夜航西飞, 撒哈拉的故事, 乖，摸摸头, 最好金龟换酒, 爱的艺术, 收纳的艺术, 家, 北欧风格小屋, 失踪的孩子, 失踪的孩子, 撒哈拉的故事, 我们仨, 失踪的孩子, ﻿我们仨, 撒哈拉的故事, 当我谈跑步时我谈些什么, 梦里花落知多少, 四个春天, 孩子你慢慢来, 我们仨, ﻿我们仨, 撒哈拉的故事, 梦里花落知多少, 孩子你慢慢来, 当我谈跑步时我谈些什么, 雨季不再来, 文化苦旅, 当我谈跑步时我谈些什么, 牧羊少年奇幻之旅, 夏洛的网, 夏洛的网, 陶庵梦忆 西湖梦寻, 古文观止, 四个春天, 常识, 人生, 我们仨, 围城, 围城, 人类群星闪耀时, 异端的权利, 默读, 一個人住第5年, 雨季不再来, 秘密, 你一生的故事, 盗墓笔记, 默读, 鬼吹灯之精绝古城, 盗墓笔记, 鬼吹灯之精绝古城, 一個人住第5年, 秘密, ﻿默读, 默读.2, 默读.3, 就这么漂来漂去, ﻿盗墓笔记, 鬼吹灯之精绝古城, 默读, ﻿撒哈拉的故事, 梦里花落知多少, 雨季不再来, 撒哈拉的故事, 哭泣的骆驼, 撒哈拉的故事, 温柔的夜, 撒哈拉的故事, 稻草人手记, 雨季不再来, 梦里花落知多少, 你是我不及的梦, 温柔的夜, 送你一匹马, 稻草人手记, 亲爱的三毛, 你一生的故事, 素年锦时, 月童度河, 素年锦时, 且以永日, 阿加莎·克里斯蒂的真实人生, ﻿雪落香杉树, 我不是完美小孩, 又寂寞又美好, 我不是完美小孩, 又寂寞又美好, 一個人住第5年, 爱的艺术, 牧羊少年奇幻之旅, 我们仨, 阿加莎·克里斯蒂的真实人生, 文学回忆录（全2册）, 文学回忆录（全2册）, 贾想II, ﻿我们仨, 我们仨, 文学回忆录（全2册）, 古文观止, 文学回忆录（全2册）, 人类群星闪耀时, 人间草木, 第三帝国的兴亡（上中下）, 所有我们看不见的光, 第三帝国的兴亡（上中下）, 正见, 正见, 撒哈拉的故事, 牧羊少年奇幻之旅, 失踪的孩子, 孩子你慢慢来, 人生, ﻿撒哈拉的故事, 乖，摸摸头, 撒哈拉的故事, 文化苦旅, 撒哈拉的故事, 撒哈拉的故事, 我们仨, 撒哈拉的故事, 当我谈跑步时我谈些什么, 默读, 爱的艺术, 牧羊少年奇幻之旅, 人生, 失踪的孩子, 孩子你慢慢来, 日食记, 生活，是很好玩的, ﻿撒哈拉的故事, 文化苦旅, 哭泣的骆驼, 撒哈拉的故事, 爱的艺术, 生活工艺时代, 家
# ========================================
# Cluster 4 details:
# --------------------
# Key features: ['中国', '本书', '作者', '日本', '美国']
# book in this cluster:
# 房思琪的初戀樂園, 活着, 双峰: 神秘史, 围城, 戴上手套擦泪, 外婆的道歉信, 戴上手套擦泪, 房思琪的初戀樂園, 外婆的道歉信, 活着, 双峰: 神秘史, 这些人，那些事, 时间的果, 下雨天一个人在家, 我为你洒下月光, 吃鲷鱼让我打嗝, 孤独六讲, ﻿活着, 围城, 北鸢, 活着本来单纯, 时间的果, 我为你洒下月光, 一只特立独行的猪, 围城, 心理学与生活, 冷暴力, 恋情的终结, 山海经全译, 中国历代政治得失, 國史大綱（上下）, 东京本屋, 人间失格, 百鬼夜行 阳, 金色梦乡, 下雨天一个人在家, 不思议图书馆, 1Q84 BOOK 1, 活着本来单纯, 这些人，那些事, 时间的果, 我为你洒下月光, 此生多珍重, 悲伤与理智, 一个人的村庄, 冬牧场, 所谓好玩的事，我再也不做了, 1Q84 BOOK 1, 1Q84 BOOK 2, 大萝卜和难挑的鳄梨, 远方的鼓声, 舞！舞！舞！, 没有女人的男人们, 无比芜杂的心绪, 1Q84 BOOK 3, 爱吃沙拉的狮子, 东京奇谭集, 遇到百分之百的女孩, ﻿一只狼在放哨, 鲍勃·迪伦诗歌集 (1961-2012), 万物静默如谜, 海子诗全集, 事物的味道，我尝得太早了, 诗的八堂课, 奥克诺斯, 博尔赫斯诗选, 唯有孤独恒常如新, 飞鸟集, 月光落在左手上, 摇摇晃晃的人间, 恶之花, 给孩子的诗, 二十亿光年的孤独, 荒原, 夜莺与玫瑰, 猜猜我有多爱你, 七夜物语, 失物之书, 银河铁道之夜, 小毛驴与我, 狐狸的窗户, 一只特立独行的猪, 王小波全集, 理想国与哲人王, 假如你愿意你就恋爱吧, 万寿寺, 东宫·西宫, 三十而立, 一只特立独行的猪, 王小波全集, 退步集, 佛祖在一号线, 角儿, 我执, 门萨的娼妓, 自由在高处, 幻想图书馆, 理想国与哲人王, 写在人生边上 人生边上的边上 石语, 普通读者, 给孩子的故事, 这就是二十四节气, 猜猜我有多爱你, 七夜物语, 梦书之城, 深夜小狗神秘事件, 山海经全译, 人间词话, 金瓶梅, 诗经, 闲情偶寄, 东京梦华录, 诗词会意：周汝昌评点中华好诗词, 声律启蒙, 山海经, 牡丹亭, 既见君子, 大好河山可骑驴, 唐宋词十七讲, 叶嘉莹说汉魏六朝诗, 悲惨世界（上中下）, 四世同堂, ﻿活着, 第七天, 现实一种, 兄弟（下）, 音乐影响了我的写作, 温暖和百感交集的旅程, 我没有自己的名字, 我能否相信自己, 黄昏里的男孩, ﻿半生缘, 张爱玲文集, 流言, 色，戒, 红楼梦魇, 第一炉香, 雷峰塔, 怨女, 传奇(上下), 张看（上下）, 传奇, 北鸢, 棋王, 苍老的指甲和宵遁的猫, 额尔古纳河右岸, 望春风, 动物凶猛, 棋王.樹王.孩子王, 城门开, ﻿围城, 写在人生边上 人生边上的边上 石语, 管锥编（全五册）, 七缀集, 谈艺录, 宋诗选注, 围城 / 人·兽·鬼, 容安馆札记, 钱锺书英文文集, 钱锺书手稿集•中文笔记, 钱钟书选集·散文卷，小说诗歌卷, 旧文四篇, 钱锺书手稿集•外文笔记（第一辑）, 钱钟书文集, 钱钟书杨绛散文, 槐聚心史, 悲惨世界（上中下）, 安娜·卡列尼娜（上下）, 堂吉诃德, 丧钟为谁而鸣, 鲁迅全集（2005最新修订版）, 阿Q正传, 朝花夕拾, 狂人日记, 伤逝, 中国小说史略, 两地书, 鲁迅与当代中国, 热风, 鲁迅全集(1), 山海经全译, 人间词话, 金瓶梅, 诗经, 闲情偶寄, 东京梦华录, 诗词会意：周汝昌评点中华好诗词, 声律启蒙, 山海经, 牡丹亭, 既见君子, 大好河山可骑驴, 唐宋词十七讲, 叶嘉莹说汉魏六朝诗, 心灵的焦灼, 斯·茨威格中短篇小说选, 一个政治性人物的肖像, 变形的陶醉, 玛丽·斯图亚特, 不朽, 雅克和他的主人, 米兰·昆德拉传, 广岛之恋, 杜拉斯谈杜拉斯, 琴声如诉, 写作, 杜拉斯传, 抵挡太平洋的堤坝, 长别离, 玛格丽特·杜拉斯, 外面的世界, ﻿生死桥, 树犹如此, 夏宇詩集／Salsa, 孤獨，或類似的東西, 東課樓經變, 周夢蝶詩文集, 七声, 無愛紀, 她是女子，我也是女子, 简媜散文, 天工开物·栩栩如真, 我城, 荒人手记, ﻿疯狂艺术史：从达芬奇到伦勃朗, 深夜食堂 01, 封闭式车库, 画的秘密, 切尔诺贝利之花, 伊甸园世界01：星之上, 我在伊朗长大, 再一次, 方向, 睡魔1：前奏与夜曲, 守望者 上, 我可以咬一口吗, 塔希里亚故事集, 无人生还, 金色梦乡, 玫瑰的名字, S., 清明上河图密码, 雪人, 长夜难明, 福尔摩斯探案全集（上中下）, 明镜之书, 希腊棺材之谜, 夏日启示录, ZOO, ﻿你今天真好看, 我可以咬一口吗, 地图（人文版）, 活了100万次的猫, 画的秘密, 猜猜我有多爱你, 塞拉菲尼抄本, 生活三部曲：生活的样子, Yaxin, le faune Gabriel, 你看起来好像很好吃, 秘密花园, 睡不着：Tango一日一画, 阿狸·梦之城堡, 朝花惜时, 我不喜欢这世界，我只喜欢你, 动物凶猛, 余生，请多指教, 少年巴比伦, 沉睡的人鱼之家, 新参者, 时生, 雪地殺機, 圣女的救济, 拉普拉斯的魔女, 流星之绊, 单恋, 超·杀人事件, 三体Ⅱ, 火星救援, 封闭式车库, 华氏451, 摩天楼, 三体全集, 软件体的生命周期, 偏爱你的甜, 岛屿之书, 11处特工皇妃, 鹤唳华亭, 夜旅人, 三生三世 枕上书, 四月间事, 孤城闭, 原来你还在这里, 双峰: 神秘史, 七根凶简, S., 清明上河图密码, 雪人, 长夜难明, 清明上河图密码4, 明镜之书, 锦衣行, 直到那一天, 神雕侠侣, 射雕英雄传（全四册）, 有匪2：离恨楼, 七夜雪, 刀背藏身, 剑桥倚天屠龙史, 倚天屠龙记(共四册), ﻿贝伦与露西恩, 碟形世界：猫和少年魔笛手, 美国众神, 冰与火之歌, 草原动物园, 睡魔1：前奏与夜曲, 无根之木, 吉尔莫·德尔·托罗的奇思妙想, 二代目归来, 九州·缥缈录, 睡魔2：玩偶之家, 塔希里亚故事集, 塞拉菲尼抄本, 精灵宝钻, 有顶天家族, 大叔上等, 灌篮高手31, 机器猫哆啦A梦23, 浪客行 1, 非法侵入(01), 死亡筆記 1, 竹光侍 1, 天是红河岸, 20世紀少年01, 萤火之森, PRIDE (下巻) (爆男COMICS), 我可以被擁抱嗎？因為太過寂寞而叫了蕾絲邊應召, PRIDE, 光明与磊落, 可爱的洪水猛兽, 青春, 长安乱, 所有人问所有人, 杂的文, 韩寒五年文集（上下）, 飄移中國, ﻿魔道祖师, 桃花债 上, 大哥, 桃花债, 義父～梅花日記～, 不可抗力 上, 關照你的花蕾, 成化十四年, 麒麟之与子同袍, 同級生, 我爱摇滚乐, 不疯魔不成活, mother, 山河表里, 乱世为王（上卷）, ﻿我的前半生, 流金岁月, 圆舞, 玫瑰的故事, 承欢记, 亦舒作品集(共60册), 寒武纪, 她的二三事, 印度墨, 亦舒新经典, 亦舒作品系列, 金色梦乡, S., 长夜难明, 希腊棺材之谜, 夏日启示录, 清明上河图密码4, 占星术杀人魔法, 13．67, 敲响密室之门, 首无·作祟之物, 傾城, 琅琊榜, 11处特工皇妃, 鹤唳华亭, 怨氣撞鈴1·食骨, 魔道祖师, ﻿莲花, 七月与安生, 眠空, 清醒纪, 安妮宝贝系列, 月, 悲伤逆流成河, 左手倒影，右手年华。, 爵迹•燃魂书, 小时代1.5·青木时代VOL.2, ﻿11处特工皇妃, 夜旅人, 大唐明月1·风起长安, 醉玲珑（上卷）, 不负如来不负卿1, 史上第一混乱·第一季神仙预备役, 扶摇皇后（上下）, 独步天下（上下卷）, 歌尽桃花, 新宋·十字1, 第一风华1·天赐良缘（上下）, 官居一品（全七册）, 神雕侠侣, 射雕英雄传（全四册）, 倚天屠龙记(共四册), 金庸江湖志, 白马啸西风, 金庸随想录, 连城诀, 金庸散文集, ﻿不干了！我开除了黑心公司, 春宵苦短，少女前進吧！, 迟来的翅膀, 未聞花名（上）, 四叠半神话大系, 末日時在做什麼？有沒有空？可以來拯救嗎？ 01, 空之境界（上）, 奇诺之旅I, Fate/Zero Vol.1 [第四次圣杯战争秘话], 斬首循環, 言叶之庭, 冰菓, 刀剑神域 01, 古书堂事件手帖 01, 圖書館戰爭, 狼與辛香料, 少女不十分, 三日間的幸福, 无人生还, 死亡之犬, 幕后凶手, 告诉我，你怎样去生活, ABC谋杀案, 大侦探波洛精选集, 牙医谋杀案, 奉命谋杀, 捕鼠器, 啤酒谋杀案, 悬崖山庄奇案, 谋杀启事, 斯泰尔斯庄园奇案, 星空, 月亮忘記了, 世界別為我擔心, 我只能為你畫一張小卡片, 我的世界都是你, 幾米創作10年精選, 照相本子, 布瓜的世界, 谢谢你毛毛兔，这个下午真好玩, 碟形世界：猫和少年魔笛手, 三体Ⅱ, 火星救援, 三体全集, 软件体的生命周期, 少数派报告, 深渊上的火, ﻿朝花惜时, 十六夜膳房, 少年巴比伦, 夏洛克是我的名字, 停靠，一座城, 我还是很喜欢你, 拂过冬季到云来, 我有一切的美妙, 这世界正在遗忘不改变的人, 七根凶简, 冰与火之歌, 大师和玛格丽特, 精灵宝钻, 魔戒前传, 冰与火之歌（卷三）, 冰与火之歌（卷二）, ﻿生死桥, 我执, 13．67, 她是女子，我也是女子, 三十年细说从头 (上下), WKW, 别来无恙, 龙头凤尾, 無愛紀, 青蛇, 穿KENZO的女人, 星空, 月亮忘記了, 世界別為我擔心, 我只能為你畫一張小卡片, 我的 ...
# ========================================
# Cluster 5 details:
# --------------------
# Key features: ['影响力', '发生', '之间', '南方', '运用']
# book in this cluster:
# 百年孤独, 追风筝的人, 1984, ﻿百年孤独, 追风筝的人, 1984, 飘, ﻿百年孤独, 1984, 追风筝的人, 送你一颗子弹, 瓦尔登湖, 送你一颗子弹, 倾城之恋, ﻿百年孤独, 飘, 瓦尔登湖, 飘, 百年孤独, 倾城之恋, ﻿夹边沟记事, ﻿飘, ﻿人类的群星闪耀时, ﻿情人, 恶意, 恶意, 幻夜, 虚无的十字架, 华胥引（全二册）, 华胥引（全二册）, 恶意, 华胥引（全二册）, 我的错都是大人的错, 飞毡, 我的错都是大人的错, 夹边沟记事, 影响力, 加缪手记, 人类的群星闪耀时, 送你一颗子弹, 中国国家治理的制度逻辑, 1984, ﻿1984, 从一到无穷大, 中国国家治理的制度逻辑, 夹边沟记事, 加缪手记, 人类的群星闪耀时, 人类的群星闪耀时, 飘, 倾城之恋, 情人, ﻿追风筝的人, 影响力, 高难度谈话, 爱的五种语言, 高难度谈话, 爱的五种语言, 激荡三十年（下）, ﻿影响力, 大败局, 激荡三十年（下）, ﻿浪潮之巅, 大败局, 影响力, 激荡三十年（下）, 股票作手回忆录, 股票作手回忆录, ﻿影响力, 参与感, 股票作手回忆录, 激荡三十年（下）, 大败局, ﻿极简宇宙史, 从一到无穷大, 浪潮之巅, ﻿极简宇宙史, 从一到无穷大, 交互设计之路, 交互设计之路, 极简宇宙史, 交互设计之路, 交互设计之路, 追风筝的人, 百年孤独, ﻿追风筝的人, 百年孤独, 飘, 1984, ﻿追风筝的人, 百年孤独, 送你一颗子弹, 瓦尔登湖, 倾城之恋, 追风筝的人, 百年孤独, 飘, 恶意, 瓦尔登湖, 银河铁道之夜, 百年孤独, 飘, 送你一颗子弹, ﻿倾城之恋, 飘, 人类的群星闪耀时, ﻿情人, 银河铁道之夜, 恶意, 银河铁道之夜, 恶意, 幻夜, 虚无的十字架, 恶意, 幻夜, ﻿华胥引（全二册）, 倾城之恋, 华胥引（全二册）, 恶意, 幻夜, 华胥引（全二册）, 百年孤独, 我的错都是大人的错, 我的错都是大人的错, 影响力, 瓦尔登湖, 送你一颗子弹, 1984, ﻿1984, 中国国家治理的制度逻辑, 中国国家治理的制度逻辑, 从一到无穷大, 夹边沟记事, 夹边沟记事, 加缪手记, 人类的群星闪耀时, 飘, 倾城之恋, 情人, ﻿追风筝的人, 飘, 影响力, 飘, 倾城之恋, 情人, 爱的五种语言, 爱的五种语言, 高难度谈话, 爱的五种语言, 影响力, 浪潮之巅, 激荡十年，水大鱼大, 影响力, 浪潮之巅, 影响力, 激荡十年，水大鱼大, 股票作手回忆录, 浪潮之巅, ﻿影响力, 参与感, 浪潮之巅, 参与感, 股票作手回忆录, ﻿激荡十年，水大鱼大, 大败局, 激荡三十年（下）, 大败局Ⅱ, 大败局Ⅱ, 从一到无穷大, ﻿浪潮之巅, 参与感, 从一到无穷大, 极简宇宙史, 浪潮之巅, 交互设计之路, 交互设计之路, 交互设计之路
# ========================================
# Cluster 6 details:
# --------------------
# Key features: ['我们', '历史', '人类', '社会', '文明']
# book in this cluster:
# ﻿解忧杂货店, 囚鸟, 囚鸟, 活着为了讲述, 灯塔, 囚鸟, 活着为了讲述, 民主的细节, ﻿解忧杂货店, 来自新世界 （上下）, 穿过圩场, 现实与欲望, 蓝熊船长的13条半命, 红拂夜奔, 野火集, 写在人生边上, 蓝熊船长的13条半命, 爷爷变成了幽灵, 三国演义（全二册）, 三国演义（全二册）, 简爱, 呼啸山庄, 我们生活在巨大的差距里, 红拂夜奔, 写在人生边上, 简爱, 呼啸山庄, 茶花女, 三国演义（全二册）, 好笑的爱, 被背叛的遗嘱, 爱，谎言与写作, 重读, 遗产, 海贼王, 波丽娜, 卢浮宫的守护者, 半小时漫画中国史（修订版）, 爷爷变成了幽灵, 最好的我们, 那些回不去的年少时光, ﻿解忧杂货店, 三体Ⅲ, 基地, 来自新世界 （上下）, 海贼王, 临高启明, 大方 No.2, 刻下来的幸福时光, 临高启明, 地下铁, 三体Ⅲ, 基地, 最好的我们, 那些回不去的年少时光, 我知道你会来，所以我等, 地下铁, 文艺风象·毕业即胜利, 鲤·暧昧, 鲤·最好的时光, 鲤·因爱之名, 鲤·荷尔蒙, ﻿最好的我们, 忽而今夏, 十二幅地图中的世界史, 少有人走的路, 乌合之众, 非暴力沟通, 灯塔, ﻿哥德尔、艾舍尔、巴赫, ﻿活着为了讲述, 历史深处的忧虑, 十二幅地图中的世界史, 你一定爱读的极简欧洲史, 最好的告别, 乌合之众, 日本的八个审美意识, 最好的告别, 乌合之众, 历史深处的忧虑, 民主的细节, 历史深处的忧虑, 民主的细节, 美丽新世界, 旧制度与大革命, 魔鬼数学, 旧制度与大革命, 民主的细节, 活着为了讲述, 见证, 穿过圩场, 智识分子, 疯癫与文明, 如何读中国画, 如何读中国画, 雪域求法记, 战略, 野蛮大陆, 奥斯维辛, 我是女兵,也是女人, 疯癫与文明, 天国之秋, 黄泉下的美术, 自由选择, 如何看一幅画, 带一本书去巴黎, 旅行的艺术, 无声告白, 小家，越住越大, 少有人走的路, 无声告白, 钓鱼的男孩, ﻿少有人走的路, 少有人走的路, 乌合之众, 非暴力沟通, 我们时代的神经症人格, 醒来的女性, 提问的力量, 职场动物进化手册, 孩子：挑战, 带一本书去巴黎, 旅行的艺术, 亲密关系, 一念之转, 吃货的生物学修养, 病者生存, 非暴力沟通, 莉莉和章鱼, 我们为什么会分手？, 求医不如求己, 零起点学中医, 我要内脏变年轻, 呼吸之间, 瑜伽之光, 非暴力沟通实践篇, ﻿小家，越住越大, 伦敦, 青海/藏羚羊自助旅行手册, 经济学通识, 伟大的博弈, 自由选择, 怪诞行为学, 经济学通识, 伟大的博弈, 自由选择, 怪诞行为学, 智能时代, 伟大的博弈, 公司理财, 引爆点, 街头生意经, 我们在为什么样的广告买单, 规模与范围, 哥德尔、艾舍尔、巴赫, 智能时代, 信息简史, 上瘾, 科技想要什么, Python编程快速上手, 哥德尔、艾舍尔、巴赫, ﻿智能时代, 文明之光（第一册）, 信息简史, 科技想要什么, 信息简史, 随意搜寻, ﻿解忧杂货店, 三体Ⅲ, 简爱（英文全本）, 解忧杂货店, 茶花女, 解忧杂货店, 三体Ⅲ, 简爱（英文全本）, 三体Ⅲ, ﻿解忧杂货店, 没有色彩的多崎作和他的巡礼之年, 地下铁, 三国演义（全二册）, 简爱（英文全本）, 三国演义（全二册）, 茶花女, 呼啸山庄, 红拂夜奔, 野火集, 有话说, 我们生活在巨大的差距里, 红拂夜奔, 写在人生边上, 简爱（英文全本）, 呼啸山庄, 茶花女, 不能承受的生命之轻, 生命中不能承受之轻, 好笑的爱, 被背叛的遗嘱, 爱，谎言与写作, 非平面, 半小时漫画世界史, 成功的聪明人太多了，我必须为笨蛋争口气！, 半小时漫画中国史（修订版）, 海贼王, 半小时漫画中国史2, 半小时漫画中国史3, 解忧杂货店, 成功的聪明人太多了，我必须为笨蛋争口气！, 地下铁, 半小时漫画世界史, 最好的我们, 那些回不去的年少时光, ﻿解忧杂货店, 三体Ⅲ, 火星孤儿, 那些回不去的年少时光, ﻿海贼王, 万水千山走遍, 三体Ⅲ, 火星孤儿, 临高启明, 来自新世界 （上下）, ﻿那些回不去的年少时光, 最好的我们, 我在未来等你, 地下铁, 地下铁, 我的错都是大人的错, 时光电影院, 请至少爱一个像男人的男人, ﻿最好的我们, ﻿鲤·时间胶囊, 鲤·最好的时光, 鲤·因爱之名, 三国演义（全二册）, 你一定爱读的极简欧洲史, 半小时漫画世界史, 今日简史, 乌合之众, 少有人走的路, 非暴力沟通, 无声告白, 世界观（原书第2版）, 三体Ⅲ, 乌合之众, 非平面, 乌合之众, 今日简史, 最好的告别, 民主的细节, 乌合之众, 你一定爱读的极简欧洲史, 历史深处的忧虑, 非平面, 乌合之众, 今日简史, 非平面, 小家，越住越大, 民主的细节, 历史深处的忧虑, 美丽新世界, 旧制度与大革命, 贾想 I, 如何写影评, ﻿民主的细节, 旧制度与大革命, 哥德尔、艾舍尔、巴赫, 半小时漫画中国史2, 活着为了讲述, 野火集, ﻿如何听爵士, 哥德尔、艾舍尔、巴赫, 向大师学绘画, 疯癫与文明, 奥斯维辛, 野蛮大陆, 偷书贼, 我是女兵,也是女人, 天国之秋, 南北战争三百年, 第五次开始, 自由选择, 自由的基因, 如何看一幅画, 向大师学绘画, 简爱（英文全本）, 茶花女, 无声告白, 少有人走的路, 最好的我们, 旅行的艺术, 带一本书去巴黎, 无声告白, 小家，越住越大, 少有人走的路, 乌合之众, 非暴力沟通, 少有人走的路, 简爱（英文全本）, 茶花女, 单身女性的时代, 非暴力沟通, 远见, 职场动物进化手册, 带一本书去巴黎, 吃货的生物学修养, 非暴力沟通, ﻿非暴力沟通, 非暴力沟通, 单身女性的时代, 我们为什么会分手？, 斯坦福高效睡眠法, 求医不如求己, 我要内脏变年轻, ﻿小家，越住越大, ﻿薛兆丰经济学讲义, 薛兆丰经济学讲义, 经济学通识, 大局观, 薛兆丰经济学讲义, 薛兆丰经济学讲义, 伟大的博弈, 薛兆丰经济学讲义, 引爆点, 上瘾, 好好赚钱, 世界观（原书第2版）, 非平面, 基因传, 你一定爱读的极简欧洲史, 今日简史, 自私的基因, 智能时代, 上瘾, Python编程快速上手, 世界观（原书第2版）, 哥德尔、艾舍尔、巴赫, 基因传, 生命3.0, 算法之美, ﻿智能时代, AI·未来, 文明之光（第一册）, 创新者, 生命3.0, 人工智能, 信息简史, 信息简史
# ========================================
# Cluster 7 details:
# --------------------
# Key features: ['哈利', '波特', '姨父', '系列', '魔法']
# book in this cluster:
# 哈利·波特与魔法石, 哈利·波特与阿兹卡班的囚徒, 哈利·波特与火焰杯, 哈利·波特与死亡圣器, 哈利·波特与密室, 哈利·波特与混血王子, 哈利·波特与凤凰社, ﻿哈利·波特与魔法石, 哈利·波特与阿兹卡班的囚徒, 哈利·波特与火焰杯, 哈利·波特与死亡圣器, 哈利·波特与密室, 哈利·波特与混血王子, 哈利·波特与凤凰社, 诗翁彼豆故事集, 哈利·波特百科全书, 哈利·波特百科全书, 哈利·波特与魔法石, 哈利·波特与魔法石, 哈利·波特与阿兹卡班的囚徒, 哈利·波特与密室, 哈利·波特与火焰杯, 哈利·波特与魔法石, 哈利·波特与阿兹卡班的囚徒, 哈利·波特与密室, 哈利·波特与火焰杯, 哈利·波特与凤凰社, 哈利·波特与死亡圣器, ﻿哈利·波特与魔法石, 哈利·波特与阿兹卡班的囚徒, 哈利·波特与密室, 哈利·波特与火焰杯, 哈利·波特与混血王子, 哈利·波特与死亡圣器, 哈利·波特与凤凰社, ﻿哈利·波特与魔法石, 哈利·波特与阿兹卡班的囚徒, 哈利·波特与火焰杯, 哈利·波特与密室, 哈利·波特与混血王子, 哈利·波特与凤凰社, 哈利·波特与死亡圣器, ﻿哈利·波特与魔法石, 哈利·波特与阿兹卡班的囚徒, 哈利·波特与密室, 哈利·波特与火焰杯, 哈利·波特与混血王子, 哈利·波特与死亡圣器, 哈利·波特与凤凰社, 诗翁彼豆故事集, 神奇动物在哪里
# ========================================
# Cluster 8 details:
# --------------------
# Key features: ['设计', '用户', '交互', '产品', '体验']
# book in this cluster:
# 纽约无人是客, 写给大家看的设计书（第3版）, 素描的诀窍, ﻿设计中的设计, 写给大家看的设计书（第3版）, 简约至上, 设计心理学, 版式设计原理, 设计的觉醒, 深泽直人, 平面设计中的网格系统, 认知与设计, 街道的美学, ﻿素描的诀窍, ﻿素描的诀窍, 纽约无人是客, 纽约无人是客, 摄影构图与色彩设计, 纽约无人是客, 住宅设计解剖书, 装修设计解剖书, 合适, 合适, 畅销的原理, 产品经理的第一本书, 简约至上, 设计心理学, 点石成金, About Face 3 交互设计精髓, 认知与设计, 破茧成蝶：用户体验设计师的成长之路, 人人都是产品经理, 赢在用户, 设计师要懂心理学, Web界面设计, 交互设计沉思录, 触动人心, Web表单设计, 简约至上, 设计心理学, 点石成金, About Face 3 交互设计精髓, 认知与设计, 破茧成蝶：用户体验设计师的成长之路, 人人都是产品经理, 赢在用户, 设计师要懂心理学, Web界面设计, 交互设计沉思录, 触动人心, Web表单设计, HTML & CSS设计与构建网站, 形式感+：网页视觉设计创意拓展与快速表现, ﻿点石成金, 设计心理学, About Face 3 交互设计精髓, 破茧成蝶：用户体验设计师的成长之路, 赢在用户, 简约至上, 交互设计沉思录, Web界面设计, Web表单设计, Designing Interfaces中文版, 用户体验度量, 形式感+：网页视觉设计创意拓展与快速表现, 用户体验面面观, 写给大家看的设计书, ﻿About Face 3 交互设计精髓, 认知与设计, 破茧成蝶：用户体验设计师的成长之路, 赢在用户, 交互设计沉思录, 触动人心, 用户体验草图设计, 在你身边，为你设计, 用户体验面面观, 决胜UX, 设计调研, 移动设计, 亲爱的界面, UCD火花集, 赢在用户, 用户体验草图设计, Web表单设计, 用户体验面面观, 设计沟通十器, UCD火花集, 一目了然, 人机交互：以用户为中心的设计和评估, 就这么简单, 重塑用户体验, 体验设计白书, Matlab神经网络与应用, 设计中的设计, ﻿设计中的设计, 写给大家看的设计书（第3版）, 设计中的设计 | 全本, 设计的意义, 日本设计六十年, 设计心理学, 设计入门教室：设计的基本规则, 简约至上, 平面设计中的网格系统, 点石成金, 设计中的设计, 街道的美学, 素描的诀窍, 素描的诀窍, 摄影构图与色彩设计, 摄影师的视界, 住宅设计解剖书, 设计准则, 人人都是产品经理, ﻿简约至上, About Face 4: 交互设计精髓, 用户体验要素, 点石成金, 破茧成蝶：用户体验设计师的成长之路, 设计心理学, 认知与设计, About Face 3 交互设计精髓, 破茧成蝶2, 人人都是产品经理, 认知与设计, 设计心理学, 点石成金, 交互设计沉思录, 设计心理学1, About Face 3：交互设计精髓, 写给大家看的设计书（第3版）, ﻿用户体验要素, 点石成金, 简约至上, 破茧成蝶：用户体验设计师的成长之路, 设计心理学, About Face 4: 交互设计精髓, 人人都是产品经理, 用户思维+：好产品让用户为自己尖叫, 赢在用户, 以匠心，致设计：网易 UEDC 用户体验设计, 用户体验度量：收集、分析与呈现（第2版）（全彩）, 认知与设计, 设计心理学1, 设计心理学, 破茧成蝶2, 写给大家看的设计书（第3版）, 点石成金, Web表单设计, ﻿用户体验要素, 简约至上, 赢在用户, About Face 3：交互设计精髓, About Face 3 交互设计精髓, 设计心理学, 用户体验度量, 在你身边，为你设计, Sketch交互设计之美, 精益设计, Designing Interfaces中文版, ﻿破茧成蝶：用户体验设计师的成长之路, 认知与设计, About Face 4: 交互设计精髓, About Face 3 交互设计精髓, 以匠心，致设计：网易 UEDC 用户体验设计, 交互设计沉思录, 认知与设计, Sketch交互设计之美, About Face 3：交互设计精髓, 在你身边，为你设计, 亲爱的界面, 设计调研, 关键设计报告, 决胜UX, ﻿赢在用户, About Face 3 交互设计精髓, UCD火花集, 用户体验度量, Web界面设计, 设计心理学, 点石成金
# ========================================
# Cluster 9 details:
# --------------------
# Key features: ['硅谷', '创业', '公司', '黑客', '管理']
# book in this cluster:
# 红楼梦, 红楼梦, ﻿红楼梦, ﻿红楼梦, ﻿红楼梦, 天龙八部, ﻿天龙八部, 鞋狗, 30天学会绘画, 30天学会绘画, 高效能人士的七个习惯（精华版）, 向前一步, 向前一步, 认识商业, 创业维艰, 高效能人士的七个习惯（精华版）, 认识商业, 精益创业, 从0到1, 创新者的窘境, 重新定义公司, 营销管理, 认识商业, 创业维艰, 认识商业, 精益创业, 从0到1, 创新者的窘境, 重新定义公司, 鞋狗, 价值评估, 巴菲特致股东的信, 价值评估, 股市真规则, 营销管理, 文案创作完全手册, 增长黑客, ﻿创业维艰, 黑客与画家, 精益创业, 从0到1, 创新者的窘境, 鞋狗, 增长黑客, 重新定义公司, 精益创业实战, 四步创业法, 巴菲特致股东的信, 文案创作完全手册, 股市真规则, 巴菲特致股东的信, 黑客与画家, 创业维艰, 从0到1, 重新定义公司, 精益创业, 增长黑客, 硅谷之谜, 黑客与画家, 从0到1, 重新定义公司, 硅谷之谜, ﻿Neural Networks and Deep Learning, 红楼梦, 红楼梦, 红楼梦, 红楼梦, ﻿红楼梦, ﻿红楼梦, ﻿天龙八部, ﻿天龙八部, 规模, 30天学会绘画, 30天学会绘画, 红楼梦, 原则, 向前一步, OKR工作法, ﻿原则, OKR工作法, 高效能人士的七个习惯（精华版）, 重新定义公司, 从0到1, ﻿原则, 从0到1, 硅谷增长黑客实战笔记, 规模, 重新理解创业, ﻿原则, 原则, 巴菲特致股东的信, 硅谷增长黑客实战笔记, 营销管理, 文案创作完全手册, 从0到1, 重新理解创业, 创业维艰, 黑客与画家, 精益创业, 鞋狗, 创新者的窘境, 四步创业法, 文案创作完全手册, 股市真规则, 巴菲特致股东的信, 硅谷增长黑客实战笔记, 从0到1, 黑客与画家, 增长黑客, 黑客与画家, 规模, 从0到1, 下一站 火星：马斯克、贝佐斯和太空争夺战, 硅谷之谜, Neural Networks and Deep Learning
# ========================================

# %%
import matplotlib.pyplot as plt
from sklearn.manifold import MDS
from sklearn.metrics.pairwise import cosine_similarity
import random
from matplotlib.font_manager import FontProperties

# %%
plot_clusters(num_clusters=num_clusters,
              feature_matrix=feature_matrix,
              cluster_data=cluster_data,
              book_data=book_data,
              plot_size=(16, 8))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-13-a2636fe2c705> in <module>()
#       3               cluster_data=cluster_data,
#       4               book_data=book_data,
# ----> 5               plot_size=(16, 8))
#
# <ipython-input-10-70c2e2578c7f> in plot_clusters(num_clusters, feature_matrix, cluster_data, book_data, plot_size)
#      48               random_state=1)
#      49     # get coordinates of clusters in new low-dimensional space
# ---> 50     plot_positions = mds.fit_transform(cosine_distance)
#      51     x_pos, y_pos = plot_positions[:, 0], plot_positions[:, 1]
#      52     # build cluster plotting data
#
# ~\Anaconda3\lib\site-packages\sklearn\manifold\mds.py in fit_transform(self, X, y, init)
#     427             n_jobs=self.n_jobs, max_iter=self.max_iter, verbose=self.verbose,
#     428             eps=self.eps, random_state=self.random_state,
# --> 429             return_n_iter=True)
#     430
#     431         return self.embedding_
#
# ~\Anaconda3\lib\site-packages\sklearn\manifold\mds.py in smacof(dissimilarities, metric, n_components, init, n_init, n_jobs, max_iter, verbose, eps, random_state, return_n_iter)
#     252                 n_components=n_components, init=init,
#     253                 max_iter=max_iter, verbose=verbose,
# --> 254                 eps=eps, random_state=random_state)
#     255             if best_stress is None or stress < best_stress:
#     256                 best_stress = stress
#
# ~\Anaconda3\lib\site-packages\sklearn\manifold\mds.py in _smacof_single(dissimilarities, metric, n_components, init, max_iter, verbose, eps, random_state)
#     113         # Update X using the Guttman transform
#     114         dis[dis == 0] = 1e-5
# --> 115         ratio = disparities / dis
#     116         B = - ratio
#     117         B[np.arange(len(B)), np.arange(len(B))] += ratio.sum(axis=1)
#
# KeyboardInterrupt:

# %%
## 这些不知道是啥

# %%
from sklearn.cluster import AffinityPropagation
#相似性传播

def affinity_propagation(feature_matrix):
    sim = feature_matrix * feature_matrix.T
    sim = sim.todense()
    ap = AffinityPropagation()
    ap.fit(sim)
    clusters = ap.labels_
    return ap, clusters


# get clusters using affinity propagation
ap_obj, clusters = affinity_propagation(feature_matrix=feature_matrix)
book_data['Cluster'] = clusters

# get the total number of books per cluster
c = Counter(clusters)
print(c.items())

# get total clusters
total_clusters = len(c)
print('Total Clusters:', total_clusters)

cluster_data = get_cluster_data(clustering_obj=ap_obj,
                                book_data=book_data,
                                feature_names=feature_names,
                                num_clusters=total_clusters,
                                topn_features=5)

print_cluster_data(cluster_data)

plot_clusters(num_clusters=num_clusters,
              feature_matrix=feature_matrix,
              cluster_data=cluster_data,
              book_data=book_data,
              plot_size=(16, 8))

from scipy.cluster.hierarchy import ward, dendrogram


def ward_hierarchical_clustering(feature_matrix):
    cosine_distance = 1 - cosine_similarity(feature_matrix)
    linkage_matrix = ward(cosine_distance)
    return linkage_matrix


def plot_hierarchical_clusters(linkage_matrix, book_data, figure_size=(8, 12)):
    # set size
    fig, ax = plt.subplots(figsize=figure_size)
    book_titles = book_data['title'].values.tolist()
    # plot dendrogram
    ax = dendrogram(linkage_matrix, orientation="left", labels=book_titles)
    plt.tick_params(axis='x',
                    which='both',
                    bottom='off',
                    top='off',
                    labelbottom='off')
    plt.tight_layout()
    plt.savefig('ward_hierachical_clusters.png', dpi=200)


# build ward's linkage matrix
linkage_matrix = ward_hierarchical_clustering(feature_matrix)
# plot the dendrogram
plot_hierarchical_clusters(linkage_matrix=linkage_matrix,
                           book_data=book_data,
                           figure_size=(8, 10))
